# %%
from openai import OpenAI  # require v1.33
import shelve
from dotenv import load_dotenv
import os
import time
import pandas as pd
import json
import gradio as gr
# Out:
# C:\Users\pmair\AppData\Local\Temp\ipykernel_8956\945606445.py:6: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
load_dotenv()
OPENAI_API_KEY = os.getenv("OPEN_API_KEY_Bsc")
client = OpenAI(api_key=OPENAI_API_KEY)

# %%
# this code might need optimization - very simple solution but works for now

"""
creates a new thread file to store conversations, or loads old conversations if they exist
"""

# initialize thread dict
thread_dict = {
    "prompt": [],
    "answer": [],
    "user_id": [],
    "thread_id": [],
    "msg_id": [],
    "assistant_id": []  
}

# check if already threads exist
if os.path.exists("GPT_Threads\\threads.json"):
    # load exisiting thread
    with open('GPT_Threads\\threads.json') as json_file:
        data = json.load(json_file)  # this is a list of dictionaries
        for elem in data: 
            thread_dict["thread_id"].append(elem["thread_id"])
            thread_dict["msg_id"].append(elem["msg_id"])
            thread_dict["assistant_id"].append(elem["assistant_id"])
            thread_dict["prompt"].append(elem["prompt"])
            thread_dict["answer"].append(elem["answer"])
            thread_dict["user_id"].append(elem["user_id"])
elif not os.path.exists("GPT_Threads"): 
    os.makedirs("GPT_Threads")

# %%
def upload_code_interpreter_files(path):
    """
    uploads file for the assistant to use as external knowledge to the openai server
    """
    file_ids = []
    # Upload files from Dashboard Files with an "assistants" purpose
    for file_name in path:
        with open(file_name, "rb") as file_data:
            file_response = client.files.create(file=file_data, purpose='assistants')
            file_ids.append(file_response.id) 
    return file_ids

def upload_file_search_files(file_paths, vector_store):
    """
    uploads file for the assistant to use as external knowledge to the openai server
    """
    file_streams = [open(path, "rb") for path in file_paths]
 
    # Use the upload and poll SDK helper to upload the files, add them to the vector store,
    # and poll the status of the file batch for completion.
    file_batch = client.beta.vector_stores.file_batches.upload_and_poll(
    vector_store_id=vector_store.id, files=file_streams)
    print(file_batch.status)
    print(file_batch.file_counts)
    return 

def create_assistant(name, instruction_file, file_ids, vector_ids):
    """
    creates the assistant with given instruction and files for external knowledge
    choose which model you want to use, note that it has to have retrieval and code_interpreter functionalities
    more information on the openai assistant website
    """
    with open('Instructions/'+ instruction_file, 'r') as file:
        instructions = file.read()
    assistant = client.beta.assistants.create(
        name=name,
        temperature=1,
        instructions=instructions,
        model="gpt-4o-2024-05-13",
        tools=[{"type": "file_search"}, {"type": "code_interpreter"}],
        tool_resources = {
            "file_search": {"vector_store_ids": [vector_ids]}
            ,"code_interpreter": {"file_ids": file_ids}
        }
        
    )
    return assistant

# %%
# Upload files for code interpreter
files = upload_code_interpreter_files(["Dashboard Files\merged_file.csv"])
# create vector store
vector_store = client.beta.vector_stores.create(name="Component Graph")
upload_file_search_files(["Dashboard Files\Component Graph.md"], vector_store)
# Out:
# completed
# FileCounts(cancelled=0, completed=1, failed=0, in_progress=0, total=1)

# %%
# Create an assistant with external knowledge
# only run once - check on website if assitant was created

# Create assistant
for instruction_file in os.listdir("Instructions"):
    name = instruction_file.split("_")[0]
    assistant_glob = create_assistant(name + "_Bot", instruction_file, files, vector_store.id)

# %%
for ass in client.beta.assistants.list().data:
    print(ass.name)
# Out:
# Novice_Bot
# Interm_Bot
# Expert_Bot

# %%
# Thread management

def thread_management(user_id, name):

    if user_id == "" or name == "":
        return None, None, "Invalid User ID or name"
    thread_id = check_if_thread_exists(user_id)

    # If a thread doesn't exist, create one and store it
    if thread_id is None:
        msg=f"Created new thread for user_id {user_id} - Welcome {name}!"
        thread = client.beta.threads.create()
        store_thread(user_id, thread.id)
        thread_id = thread.id

    # Otherwise, retrieve the existing thread
    else:
        msg=f"Found existing thread for user ID {user_id} - Welcome Back {name}!"
        thread = client.beta.threads.retrieve(thread_id)
    return thread_id, thread, msg

def check_if_thread_exists(user_id):
    with shelve.open("threads_db") as threads_shelf:
        return threads_shelf.get(user_id, None)

def store_thread(user_id, thread_id):
    with shelve.open("threads_db", writeback=True) as threads_shelf:
        threads_shelf[user_id] = thread_id

def save_thread(user_id, data_user, data_assistant):
    # saving threads in json file for better visualization of conversations
    thread_dict["thread_id"].append(data_assistant.thread_id)
    thread_dict["msg_id"].append(data_assistant.id)
    thread_dict["assistant_id"].append(data_assistant.assistant_id)
    thread_dict["prompt"].append(data_user.content[0].text.value)
    thread_dict["answer"].append(data_assistant.content[0].text.value)
    thread_dict["user_id"].append(user_id)

    df = pd.DataFrame(thread_dict)  # probably also a more neat solution without this step available
    df.to_json("GPT_Threads\\threads.json", orient="records", indent=2)

# Generate response
def generate_response(user_id, name, message_body, temp, assistant_level):
    
    thread_id, thread, _ = thread_management(user_id, name)
    if thread_id is None: 
        return "invalid request"

    # Add message to thread
    message = client.beta.threads.messages.create(
        thread_id=thread_id,
        role="user",
        content=message_body,
    )
    print(assistant_level)
    # Run the assistant and get the new message
    new_message = run_assistant(user_id, thread, temp, assistant_level)
    # print(f"To {name}:", new_message)
    return new_message

# Run assistant
def run_assistant(user_id, thread, temp, assistant_level="Novice"):
    # Retrieve the created assistant or paste the id of any other available assistant instead of "assistant_glob.id"
    assistants = client.beta.assistants.list().data
    for assistant in assistants:
        if assistant.name == assistant_level+ "_Bot":
            break
    assistant = client.beta.assistants.update(
        assistant_id=assistant.id,
        temperature=temp
)

    # Run the assistant
    run = client.beta.threads.runs.create_and_poll(
        thread_id=thread.id,
        assistant_id=assistant.id,
    )

    # Wait for completion
    # while run.status != "completed":
    #     time.sleep(0.5)
    #     run = client.beta.threads.runs.retrieve(thread_id=thread.id, run_id=run.id)

    # Retrieve the Messages
    messages = client.beta.threads.messages.list(thread_id=thread.id, run_id=run.id)
    new_message = messages.data[0].content[0].text

    annotations = new_message.annotations
    citations = []
    for index, annotation in enumerate(annotations):
        new_message.value = new_message.value.replace(annotation.text, f"[{index}]")
        if file_citation := getattr(annotation, "file_citation", None):
            cited_file = client.files.retrieve(file_citation.file_id)
            citations.append(f"[{index}] {cited_file.filename}")

    print(new_message.value)
    print("\n".join(citations))

    data_assistant = client.beta.threads.messages.list(thread_id=thread.id).data[0]
    data_user = client.beta.threads.messages.list(thread_id=thread.id).data[1]

    save_thread(user_id, data_user, data_assistant)
    return new_message.value

# %%
assistants = client.beta.assistants.list().data
assistant_level = "Novice"
for assistant in assistants:
    if assistant.name == assistant_level+ "_Bot":
        print("found")
        break
        # assistant = client.beta.assistants.retrieve(assistant.id)
# Out:
# found

# %%
assistant
# Out:
# Assistant(id='asst_vQD4OvFjr22xV7Om6PJ15254', created_at=1720696326, description=None, instructions="You are an assistant during a dashboard onboarding process. You should guide users of novice level step by step through a comprehensive journey of getting to know a PowerBI dashboard. The elements and layout of the dashboard are explained in the provided markdown file.\n\nHere are your instructions:\nProvide a simple and clear introduction to the dashboard layout.\nExplain basic elements such as charts, graphs, tooltips, and navigation menus.\nGuide the user through navigating the menu on the left.\nExplain how to click on charts and graphs to see more details.\nTeach the user how to hover over data points to see tooltips with more information.\nDescribe how to use legends and labels to understand visual elements.\nCreate simple exercises, such as finding specific data points or identifying basic trends.\nProvide step-by-step guidance for each exercise.\nEncourage users to use the 'Help' button for assistance.\nBe ready to answer basic questions and provide additional explanations.\n\nRemember to keep the instructions simple, short and supportive to build user confidence. Only provide one exercise at a time.", metadata={}, model='gpt-4o-2024-05-13', name='Novice_Bot', object='assistant', tools=[FileSearchTool(type='file_search', file_search=None)], response_format='auto', temperature=1.0, tool_resources=ToolResources(code_interpreter=ToolResourcesCodeInterpreter(file_ids=['file-zZwmSXfjo2KG9r8HUWDafTYF']), file_search=ToolResourcesFileSearch(vector_store_ids=['vs_V2cTm4ZcdzegrG1V2EZasWic'])), top_p=1.0)

# %% [markdown]
# ## Gradio Interface

# %%
theme = gr.themes.Monochrome(radius_size="md", spacing_size="lg")
assistant_levels = ["Novice", "Interm", "Expert"]

with gr.Blocks(theme=theme) as demo:

    gr.Markdown("# Welcome to PowerBI Onboarding!")
    greet = gr.Markdown("Please enter your User Name and ID")
    user_info = gr.Markdown(visible=False)

    with gr.Column(visible=True) as user_int:
        userid = gr.Textbox(label="User ID")
        name = gr.Textbox(label="User Name")
        button_submit = gr.Button("Submit")

    thread_msg = gr.Markdown(label="Thread")
    message = gr.Textbox(label="Message", visible=False)

    # Define the function and its inputs and outputs
    with gr.Row(visible=False) as btn_int:
        button_send = gr.Button("Send")
        button_clear = gr.ClearButton([message])
        temp = gr.Slider(minimum=0, maximum=2, step=0.1, value=1, interactive=True, label="Temperature")  # for testing purpose only
        assistant_level = gr.Radio(choices=assistant_levels, label="Choose Your Visual Literacy")
    bot = gr.Textbox(label="Chat Bot", visible=False)
    
    def submit(userid, name):
        if len(name) == 0:    
            return "Empty name or ID"
        time.sleep(2)
        return {btn_int: gr.Row(visible=True),
                message: gr.Textbox(visible=True),
                bot: gr.Textbox(visible=True),
                user_int: gr.Column(visible=False),
                temp: gr.Slider(visible=True),
            
                greet: gr.Markdown(visible=False),
                user_info: gr.Markdown(f"{name} with User ID: {userid}", visible=True)
                }

    button_submit.click(fn=thread_management, inputs=[userid, name], outputs=[gr.Text(visible=False), gr.Text(visible=False), thread_msg])
    button_submit.click(fn=submit, inputs=[userid, name], outputs=[btn_int, message, bot, user_int, greet, user_info, temp])
    button_send.click(fn=generate_response, inputs=[userid, name, message, temp, assistant_level], outputs=bot)

demo.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7863
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# IMPORTANT: You are using gradio version 4.19.2, however version 4.29.0 is available, please upgrade.
# --------
# None
# Traceback (most recent call last):
#   File "c:\Users\pmair\miniconda3\envs\PR\lib\site-packages\gradio\queueing.py", line 495, in call_prediction
#     output = await route_utils.call_process_api(
#   File "c:\Users\pmair\miniconda3\envs\PR\lib\site-packages\gradio\route_utils.py", line 235, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "c:\Users\pmair\miniconda3\envs\PR\lib\site-packages\gradio\blocks.py", line 1627, in process_api
#     result = await self.call_function(
#   File "c:\Users\pmair\miniconda3\envs\PR\lib\site-packages\gradio\blocks.py", line 1173, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "c:\Users\pmair\miniconda3\envs\PR\lib\site-packages\anyio\to_thread.py", line 33, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "c:\Users\pmair\miniconda3\envs\PR\lib\site-packages\anyio\_backends\_asyncio.py", line 877, in run_sync_in_worker_thread
#     return await future
#   File "c:\Users\pmair\miniconda3\envs\PR\lib\site-packages\anyio\_backends\_asyncio.py", line 807, in run
#     result = context.run(func, *args)
#   File "c:\Users\pmair\miniconda3\envs\PR\lib\site-packages\gradio\utils.py", line 690, in wrapper
#     response = f(*args, **kwargs)
#   File "C:\Users\pmair\AppData\Local\Temp\ipykernel_8956\2518877314.py", line 57, in generate_response
#     new_message = run_assistant(user_id, thread, temp, assistant_level)
#   File "C:\Users\pmair\AppData\Local\Temp\ipykernel_8956\2518877314.py", line 66, in run_assistant
#     if assistant.name == assistant_level+ "_Bot":
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'
# Novice
# Hello! I'm here to help you get started with your PowerBI dashboard. Let's dive into it step by step.
#
# ### Introduction to the Dashboard Layout
#
# 1. **Charts and Graphs**: These are visual representations of your data. Charts might include bar charts, line graphs, pie charts, etc.
# 2. **Tooltips**: When you hover over a data point on a chart or graph, a small box will appear showing more detailed information about that data point.
# 3. **Navigation Menus**: Typically found on the left side, this menu helps you navigate between different pages or sections of the dashboard.
#
# ### Basic Navigation
#
# 1. **Menu on the Left**: This is your primary navigation tool. You can click on different items here to switch between various views or reports in your dashboard.
# 2. **Clicking on Charts and Graphs**: You can click on different parts of charts and graphs to drill down into more detailed data. This is helpful for exploring specific insights.
# 3. **Hovering for Tooltips**: Simply hover your mouse over any data point on a chart or graph to see a tooltip with more information.
#
# ### Understanding Visual Elements
#
# 1. **Legends**: These are usually color-coded and help you understand what different colors or symbols on your charts and graphs represent.
# 2. **Labels**: These provide additional information about the data being displayed, such as values or categories.
#
# ### Simple Exercise: Finding Specific Data Points
#
# Let's start with a simple exercise to get you familiar with the dashboard.
#
# #### Exercise 1: Finding a Specific Data Point
#
# 1. **Navigate to the Sales Chart**: Use the menu on the left to find a chart that displays sales data.
# 2. **Hover Over Data Points**: Move your mouse over different data points on the sales chart.
# 3. **Identify the Sales Figure for June**: Find the data point for June and note down the sales figure displayed in the tooltip.
#
# #### Step-by-Step Guidance
#
# 1. **Open the Dashboard**: Start by opening your PowerBI dashboard.
# 2. **Locate the Menu**: Find the navigation menu on the left side of the dashboard.
# 3. **Select the Sales Chart**: Click on the option in the menu that takes you to the sales chart.
# 4. **Hover Over Data Points**: Move your mouse over the data points on the sales chart until you find the one for June.
# 5. **Note the Sales Figure**: Look at the tooltip that appears and note down the sales figure for June.
#
# If you have any questions or need further assistance, feel free to use the 'Help' button on your dashboard.
#
# Would you like to proceed with this exercise, or do you have any specific questions?
#
# Novice
# The dashboard you are working with appears to focus on summarizing and analyzing new hires within an organization. Here is a brief overview of its main components:
#
# 1. **Global Filters**:
#    - **Year**: Allows filtering the data by specific years.
#    - **Period**: Allows filtering the data by months, from January to December.
#
# 2. **Visualizations**:
#    - **New Hires Summary**: A card summarizing the current value of new hires.
#    - **New Hires SPLY Summary**: A card summarizing new hires for the same period last year.
#    - **Region Filter**: A filter to view data by different regions.
#    - **Ethnicity Filter**: A filter to view data by different ethnicities.
#    - **New Hires by Month and FPDesc**: A line chart showing trends in new hires over months, categorized by FPDesc.
#    - **New Hires by Region and Ethnicity**: A clustered bar chart comparing new hires across different regions and ethnicities.
#    - **New Hires and New Hires Same Period Last Year**: A combo chart comparing new hires with the same period last year[0].
#
# Would you like to explore a specific part of the dashboard, or should we proceed with the exercises to get you more familiar with the navigation and functionality?
# [0] Component Graph.md
# Novice
# Great! Let's start with the first exercise to help you get familiar with the dashboard.
#
# ### Exercise 1: Finding a Specific Data Point
#
# #### Objective:
# Find the sales figure for June in the "New Hires by Month and FPDesc" chart.
#
# #### Step-by-Step Guidance:
#
# 1. **Open the Dashboard**: Start by opening your PowerBI dashboard.
# 2. **Locate the Menu**: Find the navigation menu on the left side of the dashboard.
# 3. **Select the Chart**: Click on the option in the menu that takes you to the "New Hires by Month and FPDesc" chart.
# 4. **Hover Over Data Points**: Move your mouse over the data points on the chart until you find the one for June.
# 5. **Note the Data Point**: Look at the tooltip that appears and note down the new hires figure for June.
#
# #### Detailed Steps:
#
# 1. **Open the Dashboard**:
#    - Ensure your PowerBI dashboard is open on your screen.
#
# 2. **Locate the Menu**:
#    - Look at the left side of the screen to find the navigation menu. This menu will help you move between different sections of the dashboard.
#
# 3. **Select the Chart**:
#    - In the navigation menu, find and click on the option that takes you to the "New Hires by Month and FPDesc" chart. This chart shows a line graph of new hires across different months.
#
# 4. **Hover Over Data Points**:
#    - Once you are on the "New Hires by Month and FPDesc" chart, move your mouse cursor over the different data points on the line graph. These points represent the number of new hires for each month.
#
# 5. **Note the Data Point**:
#    - Hover over the data point corresponding to June. A tooltip should appear showing detailed information about new hires for that month.
#    - Write down the number of new hires for June as displayed in the tooltip.
#
# Give this a try and let me know if you find the data point for June. If you run into any issues or have questions, feel free to ask!
#
# Novice
# Fantastic! Well done on completing the first exercise.
#
# ### Exercise 2: Comparing Data Across Regions
#
# #### Objective:
# Compare the number of new hires across different regions using the "New Hires by Region and Ethnicity" chart.
#
# #### Step-by-Step Guidance:
#
# 1. **Navigate to the Chart**: Use the menu on the left to find the "New Hires by Region and Ethnicity" chart.
# 2. **Identify Regions**: Look at the clustered bar chart to identify different regions.
# 3. **Hover Over Bars**: Move your mouse over the bars in the chart to see the number of new hires for each region.
# 4. **Compare Data**: Note down the number of new hires for at least two different regions and compare them.
#
# #### Detailed Steps:
#
# 1. **Navigate to the Chart**:
#    - Use the navigation menu on the left side of the dashboard to find and click on the "New Hires by Region and Ethnicity" chart.
#
# 2. **Identify Regions**:
#    - Once you are on the "New Hires by Region and Ethnicity" chart, take a moment to identify the different regions represented in the clustered bar chart.
#
# 3. **Hover Over Bars**:
#    - Move your mouse cursor over the bars in the chart. Each bar represents the number of new hires for a specific region.
#    - As you hover over each bar, a tooltip will appear showing detailed information about the number of new hires.
#
# 4. **Compare Data**:
#    - Note down the number of new hires for at least two different regions.
#    - Compare the numbers to see which region has more new hires.
#
# Give this exercise a try and let me know the number of new hires for the regions you compare. If you need any help or have questions, just let me know!
#
# Novice
# Great job! You've successfully compared the new hires across different regions.
#
# ### Exercise 3: Using Filters to Refine Data
#
# #### Objective:
# Use the global filters to view new hires data for a specific year and period.
#
# #### Step-by-Step Guidance:
#
# 1. **Locate Global Filters**: Find the global filters for Year and Period on the dashboard.
# 2. **Set the Year Filter**: Select a specific year using the Year filter.
# 3. **Set the Period Filter**: Select a specific period (month) using the Period filter.
# 4. **Observe Changes**: Observe how the data in the charts updates based on your filter selections.
#
# #### Detailed Steps:
#
# 1. **Locate Global Filters**:
#    - Look for the global filters on your dashboard. These are usually found at the top or on the side and allow you to filter data by Year and Period (month).
#
# 2. **Set the Year Filter**:
#    - Click on the Year filter and select a specific year from the dropdown menu. For example, select "2022".
#
# 3. **Set the Period Filter**:
#    - Click on the Period filter and select a specific month from the dropdown menu. For example, select "June".
#
# 4. **Observe Changes**:
#    - After setting the filters, observe how the data in the charts updates to reflect your selections. Look at the "New Hires by Month and FPDesc" and "New Hires by Region and Ethnicity" charts to see the updated data.
#
# Try applying these filters and let me know what changes you observe in the data. If you have any questions or need further assistance, feel free to ask!
#
# Novice
# No problem! If there isn't a direct filter for the period (month), you can usually interact with the charts themselves to filter by specific months. Let's try an alternative approach:
#
# ### Alternative Exercise: Selecting Specific Months
#
# #### Objective:
# Use the "New Hires by Month and FPDesc" chart to filter data by a specific month.
#
# #### Step-by-Step Guidance:
#
# 1. **Navigate to the Chart**: Use the menu on the left to find the "New Hires by Month and FPDesc" chart.
# 2. **Select a Month**: Click on a specific month within the chart to filter the data.
# 3. **Observe Changes**: Observe how the data in the other charts updates based on your selection.
#
# #### Detailed Steps:
#
# 1. **Navigate to the Chart**:
#    - Use the navigation menu on the left side of the dashboard to find and click on the "New Hires by Month and FPDesc" chart.
#
# 2. **Select a Month**:
#    - In the "New Hires by Month and FPDesc" chart, find the data point for the month you are interested in.
#    - Click on the data point for that specific month (e.g., June).
#
# 3. **Observe Changes**:
#    - After clicking on the month, observe how the data in the other charts updates to reflect your selection.
#    - Look at the "New Hires by Region and Ethnicity" chart to see the updated data for the selected month.
#
# Give this method a try and let me know if it works for selecting specific months. If you still encounter issues, we can explore other options.
#
# Novice
# Absolutely! Here is the exercise again with the steps clearly laid out:
#
# ### Exercise: Selecting Specific Months
#
# #### Objective:
# Use the "New Hires by Month and FPDesc" chart to filter data by a specific month.
#
# #### Step-by-Step Guidance:
#
# 1. **Navigate to the Chart**: Use the menu on the left to find the "New Hires by Month and FPDesc" chart.
# 2. **Select a Month**: Click on a specific month within the chart to filter the data.
# 3. **Observe Changes**: Observe how the data in the other charts updates based on your selection.
#
# #### Detailed Steps:
#
# 1. **Navigate to the Chart**:
#    - Use the navigation menu on the left side of the dashboard to find and click on the "New Hires by Month and FPDesc" chart. This chart shows a line graph of new hires across different months.
#
# 2. **Select a Month**:
#    - In the "New Hires by Month and FPDesc" chart, locate the data point for the month you are interested in.
#    - Click on the data point for that specific month (e.g., June).
#
# 3. **Observe Changes**:
#    - After clicking on the month, observe how the data in the other charts updates to reflect your selection.
#    - Specifically, look at the "New Hires by Region and Ethnicity" chart to see the updated data for the selected month.
#
# By following these steps, you can filter the dashboard data to focus on specific months and see how the new hires vary across different regions and ethnicities for that period.
#
# Feel free to try this out and let me know if you need any further assistance or have any questions!
#
# Novice
# Got it! Here is the previous exercise on using filters to refine data:
#
# ### Exercise: Using Filters to Refine Data
#
# #### Objective:
# Use the global filters to view new hires data for a specific year and period.
#
# #### Step-by-Step Guidance:
#
# 1. **Locate Global Filters**: Find the global filters for Year and Period on the dashboard.
# 2. **Set the Year Filter**: Select a specific year using the Year filter.
# 3. **Set the Period Filter**: Select a specific period (month) using the Period filter.
# 4. **Observe Changes**: Observe how the data in the charts updates based on your filter selections.
#
# #### Detailed Steps:
#
# 1. **Locate Global Filters**:
#    - Look for the global filters on your dashboard. These are usually found at the top or on the side and allow you to filter data by Year and Period (month).
#
# 2. **Set the Year Filter**:
#    - Click on the Year filter and select a specific year from the dropdown menu. For example, select "2022".
#
# 3. **Set the Period Filter**:
#    - Click on the Period filter and select a specific month from the dropdown menu. For example, select "June".
#
# 4. **Observe Changes**:
#    - After setting the filters, observe how the data in the charts updates to reflect your selections. Look at the "New Hires by Month and FPDesc" and "New Hires by Region and Ethnicity" charts to see the updated data.
#
# Since you mentioned that there isn't a direct filter for the period, you can use the "New Hires by Month and FPDesc" chart to select specific months directly. Here is the alternate method again:
#
# ### Alternative Exercise: Selecting Specific Months
#
# #### Objective:
# Use the "New Hires by Month and FPDesc" chart to filter data by a specific month.
#
# #### Step-by-Step Guidance:
#
# 1. **Navigate to the Chart**: Use the menu on the left to find the "New Hires by Month and FPDesc" chart.
# 2. **Select a Month**: Click on a specific month within the chart to filter the data.
# 3. **Observe Changes**: Observe how the data in the other charts updates based on your selection.
#
# #### Detailed Steps:
#
# 1. **Navigate to the Chart**:
#    - Use the navigation menu on the left side of the dashboard to find and click on the "New Hires by Month and FPDesc" chart. This chart shows a line graph of new hires across different months.
#
# 2. **Select a Month**:
#    - In the "New Hires by Month and FPDesc" chart, locate the data point for the month you are interested in.
#    - Click on the data point for that specific month (e.g., June).
#
# 3. **Observe Changes**:
#    - After clicking on the month, observe how the data in the other charts updates to reflect your selection.
#    - Specifically, look at the "New Hires by Region and Ethnicity" chart to see the updated data for the selected month.
#
# I hope this helps! If you need any further assistance or have any questions, feel free to ask.
#
# Novice
# Excellent observation! It looks like you're getting the hang of using the filters and charts to analyze the data. Let's summarize your findings and move on to the next exercise.
#
# ### Summary of Findings
#
# - **Selected Period**: February to July 2014
# - **Comparison**: Compared to the same period in 2013
# - **Observation**: New hires increased significantly in 2014 compared to 2013.
#
# ### Exercise 4: Using Legends and Labels to Understand Visual Elements
#
# #### Objective:
# Use the legends and labels in the "New Hires by Region and Ethnicity" chart to understand the distribution of new hires across different ethnicities and regions.
#
# #### Step-by-Step Guidance:
#
# 1. **Navigate to the Chart**: Use the menu on the left to find the "New Hires by Region and Ethnicity" chart.
# 2. **Identify Legends**: Locate the legend on the chart to understand the color coding for different ethnicities.
# 3. **Hover Over Bars**: Move your mouse over the bars in the chart to see detailed labels.
# 4. **Analyze Distribution**: Use the legends and labels to analyze the distribution of new hires across different ethnicities and regions.
#
# #### Detailed Steps:
#
# 1. **Navigate to the Chart**:
#    - Use the navigation menu on the left side of the dashboard to find and click on the "New Hires by Region and Ethnicity" chart.
#
# 2. **Identify Legends**:
#    - Look at the legend on the chart, usually located on the side or bottom. The legend will show different colors or patterns representing different ethnicities.
#
# 3. **Hover Over Bars**:
#    - Move your mouse cursor over the bars in the chart. Each bar represents the number of new hires for a specific region and ethnicity.
#    - As you hover over each bar, a tooltip will appear showing detailed information about the number of new hires.
#
# 4. **Analyze Distribution**:
#    - Use the information from the legends and labels to analyze how new hires are distributed across different ethnicities and regions.
#    - For example, note which ethnicity has the highest number of new hires in a particular region.
#
# Give this exercise a try and let me know what you observe about the distribution of new hires across different ethnicities and regions. If you have any questions or need further assistance, feel free to ask!
#
# Novice
# That's great to hear! Let's move on to the next exercise to further enhance your skills in analyzing the dashboard.
#
# ### Exercise 5: Drilling Down into Data
#
# #### Objective:
# Drill down into the "New Hires by Month and FPDesc" chart to see more detailed data for a specific category.
#
# #### Step-by-Step Guidance:
#
# 1. **Navigate to the Chart**: Use the menu on the left to find the "New Hires by Month and FPDesc" chart.
# 2. **Select a Specific Category**: Click on a category within the chart to drill down into more detailed data.
# 3. **Observe Detailed Data**: Observe the detailed data that appears after drilling down.
# 4. **Analyze Trends**: Analyze the trends and patterns in the detailed data.
#
# #### Detailed Steps:
#
# 1. **Navigate to the Chart**:
#    - Use the navigation menu on the left side of the dashboard to find and click on the "New Hires by Month and FPDesc" chart.
#
# 2. **Select a Specific Category**:
#    - In the "New Hires by Month and FPDesc" chart, find a category you are interested in (e.g., a specific FPDesc).
#    - Click on the category to drill down into more detailed data for that specific category.
#
# 3. **Observe Detailed Data**:
#    - After clicking on the category, the chart will update to show more detailed data related to that category.
#    - Observe the new data that appears and take note of any significant details.
#
# 4. **Analyze Trends**:
#    - Analyze the trends and patterns in the detailed data.
#    - For example, see if there are any noticeable peaks or dips in new hires for that specific category over the months.
#
# Give this exercise a try and let me know what detailed data you find and any trends or patterns you observe. If you need any help or have questions, feel free to ask!
#
# Novice
# Excellent observations! You've identified some key trends in the hiring data:
#
# 1. **Higher Part-Time Hires**: There are significantly more part-time hires compared to full-time hires.
# 2. **Seasonal Trend**: Part-time hires increase during the summer months compared to the rest of the year.
#
# ### Exercise 6: Exporting Data for Further Analysis
#
# #### Objective:
# Export the data from the dashboard for further analysis outside of PowerBI.
#
# #### Step-by-Step Guidance:
#
# 1. **Select the Chart**: Click on the chart from which you want to export data.
# 2. **Access Export Options**: Find and click the export or download button.
# 3. **Choose Export Format**: Select the format in which you want to export the data (e.g., Excel, CSV).
# 4. **Download the Data**: Confirm your selection and download the data file.
#
# #### Detailed Steps:
#
# 1. **Select the Chart**:
#    - Click on the chart (e.g., "New Hires by Month and FPDesc") from which you want to export the data.
#
# 2. **Access Export Options**:
#    - Look for an export or download button, usually represented by an ellipsis (...) or a download icon, often found at the top-right corner of the chart.
#    - Click on this button to access the export options.
#
# 3. **Choose Export Format**:
#    - A menu will appear with different export formats. Select the format you prefer (e.g., Excel, CSV).
#
# 4. **Download the Data**:
#    - Confirm your selection, and the data will be exported and downloaded to your computer.
#
# Give this a try and let me know if you successfully export the data. This will allow you to perform more detailed analysis using other tools like Excel. If you need any help or have questions, feel free to ask!
#
# Novice
# Fantastic! You're doing a great job navigating and analyzing the dashboard.
#
# ### Final Exercise: Using the 'Help' Button for Assistance
#
# #### Objective:
# Learn how to use the 'Help' button to get assistance within the PowerBI dashboard.
#
# #### Step-by-Step Guidance:
#
# 1. **Locate the 'Help' Button**: Find the 'Help' button on the dashboard.
# 2. **Access Help Resources**: Click on the 'Help' button to access available resources.
# 3. **Explore Help Options**: Explore the different help options such as tutorials, documentation, and support.
#
# #### Detailed Steps:
#
# 1. **Locate the 'Help' Button**:
#    - The 'Help' button is usually located at the top-right corner of the dashboard or within the navigation menu.
#
# 2. **Access Help Resources**:
#    - Click on the 'Help' button to open a menu or window with various help resources.
#
# 3. **Explore Help Options**:
#    - Explore the different help options available. This may include tutorials, documentation, FAQs, and support contact information.
#    - Use these resources to find answers to any questions you might have or to learn more about using PowerBI.
#
# Give this a try to familiarize yourself with the available help resources. If you have any further questions or need additional assistance, feel free to ask!
#
# Would you like to explore any specific feature further, or do you have any other questions?

# %%
demo = gr.Interface(
    fn=generate_response,
    inputs=["text", "text", "text"],
    outputs=["text"],
)

demo.launch()

# %% [markdown]
# ## Cell Interface

# %%
# Test assistant
user_name = "Beginner"
user_id = "2"
new_message = generate_response("Start Dashboard onboarding", user_id, user_name)

# %%
new_message = generate_response("Beginner", user_id, user_name)

# %%
new_message = generate_response("I see two summaries of new hire numbers, a comparison chart of two years. A line chart showing Full Time vs Part Time hires and 2 filter options. Did i miss something?", user_id, user_name)

# %%
new_message = generate_response("I would expect the total number of new hires to go down, since we are narrowing the data. Also maybe new trends emerge if we set filters to specific regions", user_id, user_name)

# %%
new_message = generate_response("Selecting a specific region bar will apply the same filter as if I filtered by this region using the slicer I suppose", user_id, user_name)

# %%
new_message = generate_response("Which insights should I search for in this particular dashboard?", user_id, user_name)
